# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

entries = 1000
dfs = []
for df in pd.read_csv('../data/weather.csv', chunksize=entries):
    dfs.append(df)
    break # take 1 times 1000 entries for now, dataset is huge!
data = pd.concat(dfs)

# %%
data.tail()
# Out:
#      M_PACKET_FORMAT  M_GAME_MAJOR_VERSION  M_GAME_MINOR_VERSION  \
# 995             2021                     1                    14
# 996             2021                     1                    14
# 997             2021                     1                    14
# 998             2021                     1                    14
# 999             2021                     1                    14
#
#      M_PACKET_VERSION  M_PACKET_ID         M_SESSION_UID  M_SESSION_TIME  \
# 995                 1            1  13002103581294142936        2956.567
# 996                 1            1  13002103581294142936        2956.567
# 997                 1            1  13002103581294142936        2956.567
# 998                 1            1  13002103581294142936        2956.567
# 999                 1            1  13002103581294142936        2956.567
#
#      M_FRAME_IDENTIFIER  M_PLAYER_CAR_INDEX  M_SECONDARY_PLAYER_CAR_INDEX  \
# ...

# %%
data.columns
# Out:
# Index(['M_PACKET_FORMAT', 'M_GAME_MAJOR_VERSION', 'M_GAME_MINOR_VERSION',
#        'M_PACKET_VERSION', 'M_PACKET_ID', 'M_SESSION_UID', 'M_SESSION_TIME',
#        'M_FRAME_IDENTIFIER', 'M_PLAYER_CAR_INDEX',
#        'M_SECONDARY_PLAYER_CAR_INDEX', 'M_BRAKING_ASSIST',
#        'M_SESSION_LINK_IDENTIFIER', 'M_PIT_RELEASE_ASSIST', 'TIMESTAMP',
#        'M_ZONE_START', 'M_ZONE_FLAG', 'M_PIT_STOP_WINDOW_IDEAL_LAP',
#        'M_TRACK_TEMPERATURE', 'M_TRACK_LENGTH', 'M_GAME_PAUSED',
#        'M_FORECAST_ACCURACY', 'GAMEHOST', 'M_AIR_TEMPERATURE',
#        'M_NUM_WEATHER_FORECAST_SAMPLES', 'M_SLI_PRO_NATIVE_SUPPORT',
#        'M_SAFETY_CAR_STATUS', 'M_TRACK_ID', 'M_ERSASSIST', 'M_FORMULA',
#        'M_SEASON_LINK_IDENTIFIER', 'M_PIT_ASSIST', 'M_GEARBOX_ASSIST',
#        'M_SESSION_TYPE', 'M_SPECTATOR_CAR_INDEX',
#        'M_PIT_STOP_WINDOW_LATEST_LAP', 'M_WEEKEND_LINK_IDENTIFIER',
#        'M_DYNAMIC_RACING_LINE_TYPE', 'M_SESSION_TIME_LEFT',
# ...

# %%
for col in data.columns:
    print(col, data[col].value_counts())
    print('----------')
# Out:
# M_PACKET_FORMAT 2021    1000
# Name: M_PACKET_FORMAT, dtype: int64
# ----------
# M_GAME_MAJOR_VERSION 1    1000
# Name: M_GAME_MAJOR_VERSION, dtype: int64
# ----------
# M_GAME_MINOR_VERSION 14    1000
# Name: M_GAME_MINOR_VERSION, dtype: int64
# ----------
# M_PACKET_VERSION 1    1000
# Name: M_PACKET_VERSION, dtype: int64
# ----------
# M_PACKET_ID 1    1000
# Name: M_PACKET_ID, dtype: int64
# ----------
# M_SESSION_UID 13002103581294142936    1000
# Name: M_SESSION_UID, dtype: int64
# ----------
# M_SESSION_TIME 2803.836    77
# 2986.005    77
# 2805.899    77
# 2822.405    77
# 2838.915    77
# 2843.061    77
# 2858.393    77
# 2874.194    77
# 2890.696    77
# 2907.198    77
# 2923.700    77
# 2940.065    77
# 2956.567    76
# Name: M_SESSION_TIME, dtype: int64
# ----------
# M_FRAME_IDENTIFIER 82458    77
# 88545    77
# 82543    77
# 83229    77
# 83899    77
# 84254    77
# 84646    77
# 85062    77
# 85673    77
# 86329    77
# 86983    77
# 87459    77
# 87820    76
# ...

# %%
data.columns
# Out:
# Index(['M_PACKET_FORMAT', 'M_GAME_MAJOR_VERSION', 'M_GAME_MINOR_VERSION',
#        'M_PACKET_VERSION', 'M_PACKET_ID', 'M_SESSION_UID', 'M_SESSION_TIME',
#        'M_FRAME_IDENTIFIER', 'M_PLAYER_CAR_INDEX',
#        'M_SECONDARY_PLAYER_CAR_INDEX', 'M_BRAKING_ASSIST',
#        'M_SESSION_LINK_IDENTIFIER', 'M_PIT_RELEASE_ASSIST', 'TIMESTAMP',
#        'M_ZONE_START', 'M_ZONE_FLAG', 'M_PIT_STOP_WINDOW_IDEAL_LAP',
#        'M_TRACK_TEMPERATURE', 'M_TRACK_LENGTH', 'M_GAME_PAUSED',
#        'M_FORECAST_ACCURACY', 'GAMEHOST', 'M_AIR_TEMPERATURE',
#        'M_NUM_WEATHER_FORECAST_SAMPLES', 'M_SLI_PRO_NATIVE_SUPPORT',
#        'M_SAFETY_CAR_STATUS', 'M_TRACK_ID', 'M_ERSASSIST', 'M_FORMULA',
#        'M_SEASON_LINK_IDENTIFIER', 'M_PIT_ASSIST', 'M_GEARBOX_ASSIST',
#        'M_SESSION_TYPE', 'M_SPECTATOR_CAR_INDEX',
#        'M_PIT_STOP_WINDOW_LATEST_LAP', 'M_WEEKEND_LINK_IDENTIFIER',
#        'M_DYNAMIC_RACING_LINE_TYPE', 'M_SESSION_TIME_LEFT',
# ...

# %%
#The unique index for the dataset is (session_uid, player_car_index, timestamp)

# %%
columns_to_keep = ['M_GAME_MINOR_VERSION', 'M_SESSION_TIME',
'TIMESTAMP', 
'M_TRACK_TEMPERATURE', 'M_TRACK_LENGTH',
'M_FORECAST_ACCURACY', 
'M_AIR_TEMPERATURE',
'M_NUM_WEATHER_FORECAST_SAMPLES',
'M_TRACK_ID',
'M_WEATHER_FORECAST_SAMPLES_M_SESSION_TYPE', 'M_TIME_OFFSET',
       'M_WEATHER_FORECAST_SAMPLES_M_WEATHER',
       'M_WEATHER_FORECAST_SAMPLES_M_TRACK_TEMPERATURE',
       'M_TRACK_TEMPERATURE_CHANGE',
       'M_WEATHER_FORECAST_SAMPLES_M_AIR_TEMPERATURE',
       'M_AIR_TEMPERATURE_CHANGE', 'M_RAIN_PERCENTAGE', 'M_WEATHER']

# %%
unsure = [
    'M_SESSION_UID',
     'M_ZONE_START',
     'M_SESSION_TIME_LEFT',
     'M_SESSION_DURATION',
]

# %%
columns_to_drop = ['M_PACKET_FORMAT', 'M_GAME_MAJOR_VERSION',
       'M_PACKET_VERSION', 'M_PACKET_ID', 'M_SESSION_UID', 
        'M_PLAYER_CAR_INDEX',
       'M_SECONDARY_PLAYER_CAR_INDEX', 'M_BRAKING_ASSIST',
       'M_SESSION_LINK_IDENTIFIER', 'M_PIT_RELEASE_ASSIST',
       'M_ZONE_FLAG', 'M_PIT_STOP_WINDOW_IDEAL_LAP',
        'M_GAME_PAUSED',
       'GAMEHOST', 
        'M_SLI_PRO_NATIVE_SUPPORT',
       'M_SAFETY_CAR_STATUS',  'M_ERSASSIST', 'M_FORMULA',
       'M_SEASON_LINK_IDENTIFIER', 'M_PIT_ASSIST', 'M_GEARBOX_ASSIST',
       'M_SESSION_TYPE', 'M_SPECTATOR_CAR_INDEX',
       'M_PIT_STOP_WINDOW_LATEST_LAP', 'M_WEEKEND_LINK_IDENTIFIER',
       'M_DYNAMIC_RACING_LINE_TYPE', 
       'M_PIT_STOP_REJOIN_POSITION',
       'M_AI_DIFFICULTY', 'M_PIT_SPEED_LIMIT', 'M_NETWORK_GAME',
       'M_TOTAL_LAPS', 'M_STEERING_ASSIST', 'M_IS_SPECTATING',
       'M_DYNAMIC_RACING_LINE', 'M_DRSASSIST', 'M_NUM_MARSHAL_ZONES',
       'Unnamed: 58']

# %%
col_info = {'keep' : columns_to_keep, 'unsure': unsure, 'drop': columns_to_drop}

# %%
import json

with open('../data/columns_to_drop.json', 'w') as f:
    json.dump(col_info, f)
