# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

entries = 1000
dfs = []
for df in pd.read_csv('../data/weather.csv', chunksize=entries):
    dfs.append(df)
    break # take 1 times 1000 entries for now, dataset is huge!
data = pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\jackh\Documents\Projects\FormulaAI\F1Hackathon\code\ajpf1.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/jackh/Documents/Projects/FormulaAI/F1Hackathon/code/ajpf1.ipynb#ch0000000?line=0'>1</a> # This Python 3 environment comes with many helpful analytics libraries installed
#       <a href='vscode-notebook-cell:/c%3A/Users/jackh/Documents/Projects/FormulaAI/F1Hackathon/code/ajpf1.ipynb#ch0000000?line=1'>2</a> # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
#       <a href='vscode-notebook-cell:/c%3A/Users/jackh/Documents/Projects/FormulaAI/F1Hackathon/code/ajpf1.ipynb#ch0000000?line=2'>3</a> # For example, here's several helpful packages to load
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jackh/Documents/Projects/FormulaAI/F1Hackathon/code/ajpf1.ipynb#ch0000000?line=4'>5</a> import numpy as np # linear algebra
#       <a href='vscode-notebook-cell:/c%3A/Users/jackh/Documents/Projects/FormulaAI/F1Hackathon/code/ajpf1.ipynb#ch0000000?line=5'>6</a> import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#       <a href='vscode-notebook-cell:/c%3A/Users/jackh/Documents/Projects/FormulaAI/F1Hackathon/code/ajpf1.ipynb#ch0000000?line=7'>8</a> entries = 1000
#
# ModuleNotFoundError: No module named 'numpy'

# %%
data.tail()
# Out:
#      M_PACKET_FORMAT  M_GAME_MAJOR_VERSION  M_GAME_MINOR_VERSION  \
# 995             2021                     1                    14
# 996             2021                     1                    14
# 997             2021                     1                    14
# 998             2021                     1                    14
# 999             2021                     1                    14
#
#      M_PACKET_VERSION  M_PACKET_ID         M_SESSION_UID  M_SESSION_TIME  \
# 995                 1            1  13002103581294142936        2956.567
# 996                 1            1  13002103581294142936        2956.567
# 997                 1            1  13002103581294142936        2956.567
# 998                 1            1  13002103581294142936        2956.567
# 999                 1            1  13002103581294142936        2956.567
#
#      M_FRAME_IDENTIFIER  M_PLAYER_CAR_INDEX  M_SECONDARY_PLAYER_CAR_INDEX  \
# 995               87820                   0                           255
# 996               87820                   0                           255
# 997               87820                   0                           255
# 998               87820                   0                           255
# 999               87820                   0                           255
#
#      ...  M_AI_DIFFICULTY  M_PIT_SPEED_LIMIT  M_NETWORK_GAME  M_TOTAL_LAPS  \
# 995  ...                0                 80               0           200
# 996  ...                0                 80               0           200
# 997  ...                0                 80               0           200
# 998  ...                0                 80               0           200
# 999  ...                0                 80               0           200
#
#      M_STEERING_ASSIST  M_IS_SPECTATING  M_DYNAMIC_RACING_LINE  M_DRSASSIST  \
# 995                  0                0                      0            0
# 996                  0                0                      0            0
# 997                  0                0                      0            0
# 998                  0                0                      0            0
# 999                  0                0                      0            0
#
#      M_NUM_MARSHAL_ZONES  Unnamed: 58
# 995                   16          NaN
# 996                   16          NaN
# 997                   16          NaN
# 998                   16          NaN
# 999                   16          NaN
#
# [5 rows x 59 columns]
