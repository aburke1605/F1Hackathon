# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

entries = 35000
testing_sample = []
for df in pd.read_csv('../data/weather.csv', chunksize=entries):
    testing_sample.append(df)
    break
testing_sample = pd.concat(testing_sample)

# %%
#print(testing_sample.columns)
print(testing_sample.shape)
testing_sample.query('M_NUM_WEATHER_FORECAST_SAMPLES>0',inplace=True)
print(testing_sample.shape)
# Out:
# (35000, 59)
# (8316, 59)

# %%
testing_sample.to_csv('../data/testing_sample.csv')

# %%
testing_sample.to_csv('../data/weather_test_sample.csv')
dfs = []
for df in pd.read_csv('../data/weather.csv', chunksize=entries):
    dfs.append(df)
    break # take 1 times 1000 entries for now, dataset is huge!
data = pd.concat(dfs)
data.tail()
